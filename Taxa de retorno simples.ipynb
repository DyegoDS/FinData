# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
# Out:
# C:\Users\Dyego\anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
PG = wb.DataReader('PG', data_source='yahoo', start='1995-1-1')

# %%
PG.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.166473
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   8.101009
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.986450
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   8.002816
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.970086

# %%
PG.tail()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-03-31  136.750000  135.259995  135.679993  135.429993  9202600.0
# 2021-04-01  135.479996  133.330002  135.050003  134.279999  9116600.0
# 2021-04-05  137.250000  134.729996  134.960007  136.449997  8279100.0
# 2021-04-06  137.020004  135.639999  136.000000  136.500000  6140300.0
# 2021-04-07  137.330002  136.250000  137.119995  136.740005  7648892.0
#
#              Adj Close
# Date
# 2021-03-31  135.429993
# 2021-04-01  134.279999
# 2021-04-05  136.449997
# 2021-04-06  136.500000
# 2021-04-07  136.740005

# %%
PG['Simple Return'] = (PG['Adj Close'] / PG['Adj Close'].shift(1)) - 1

# %%
PG
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 1995-01-03   15.625000   15.437500   15.468750   15.593750  3318400.0
# 1995-01-04   15.656250   15.312500   15.531250   15.468750  2218800.0
# 1995-01-05   15.437500   15.218750   15.375000   15.250000  2319600.0
# 1995-01-06   15.406250   15.156250   15.156250   15.281250  3438000.0
# 1995-01-09   15.406250   15.187500   15.343750   15.218750  1795200.0
# ...                ...         ...         ...         ...        ...
# 2021-03-31  136.750000  135.259995  135.679993  135.429993  9202600.0
# 2021-04-01  135.479996  133.330002  135.050003  134.279999  9116600.0
# 2021-04-05  137.250000  134.729996  134.960007  136.449997  8279100.0
# 2021-04-06  137.020004  135.639999  136.000000  136.500000  6140300.0
# 2021-04-07  137.330002  136.250000  137.119995  136.740005  7648892.0
#
#              Adj Close  Simple Return
# Date
# 1995-01-03    8.166473            NaN
# ...

# %%
PG['Simple Return'].plot(figsize=(8,5))

# %%
media_diaria_r = PG['Simple Return'].mean()

# %%
media_diaria_r
# Out:
# 0.0005283269437161446

# %%
media_anual_r = PG['Simple Return'].mean()*250

# %%
media_anual_r
# Out:
# 0.13208173592903616

# %%
print (str(round(media_anual_r, 5)*100) + '%')
# Out:
# 13.208%

# %% [markdown]
#  # Retorno Logaritimic

# %%
PG['Return LOG'] = np.log(PG['Adj Close'] / PG['Adj Close'].shift(1))

# %%
PG.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close  \
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.166473
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   8.101009
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.986450
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   8.002816
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.970086
#
#             Simple Return  Return LOG
# Date
# 1995-01-03            NaN         NaN
# 1995-01-04      -0.008016   -0.008048
# 1995-01-05      -0.014141   -0.014242
# 1995-01-06       0.002049    0.002047
# 1995-01-09      -0.004090   -0.004098

# %%
media_diaria_log = PG['Return LOG'].mean()
media_diaria_log
# Out:
# 0.00042626594928886746

# %%
media_anual_log = PG['Return LOG'].mean()*250
media_anual_log
# Out:
# 0.10656648732221687

# %%
print (str(round(media_anual_log, 5)*100) + '%')
# Out:
# 10.657%

# %%
mmx = wb.DataReader('MMXM3.SA', 'yahoo', '2006-7-28')

# %%
mmx
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2006-07-28  1295.948242  1281.777710  1281.777710  1281.793457   726369.0
# 2006-07-31  1289.657227  1277.075195  1283.366211  1295.948242  1554854.0
# 2006-08-01  1305.384766  1286.511719  1305.384766  1289.657227  2705765.0
# 2006-08-02  1336.839722  1313.248535  1313.248535  1297.520996   701636.0
# 2006-08-03  1297.520996  1297.520996  1297.520996  1297.520996        0.0
# ...                 ...          ...          ...          ...        ...
# 2021-03-31    30.000000    26.510000    29.250000    27.500000   246800.0
# 2021-04-01    27.900000    24.750000    27.760000    24.750000   317500.0
# 2021-04-05    30.900000    26.120001    28.260000    30.400000   828300.0
# 2021-04-06    31.290001    27.010000    29.490000    27.790001   492600.0
# 2021-04-07     0.000000     0.000000     0.000000    27.900000        0.0
#
#               Adj Close
# Date
# 2006-07-28  1281.793457
# ...

# %%
bovespa = wb.DataReader('^BVSP', 'yahoo')

# %%
bovespa
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2016-04-11   51089.0   50078.0   50303.0   50165.0   4050700.0    50165.0
# 2016-04-12   52327.0   50166.0   50166.0   52002.0   5146900.0    52002.0
# 2016-04-13   53844.0   52010.0   52010.0   53150.0   6376500.0    53150.0
# 2016-04-14   53699.0   52242.0   53150.0   52411.0   5492100.0    52411.0
# 2016-04-15   53390.0   52414.0   52414.0   53228.0   5047800.0    53228.0
# ...              ...       ...       ...       ...         ...        ...
# 2021-03-31  117249.0  115932.0  116850.0  116634.0  10659200.0   116634.0
# 2021-04-01  117088.0  114991.0  116644.0  115253.0   8009200.0   115253.0
# 2021-04-05  117668.0  115262.0  115262.0  117518.0   7245100.0   117518.0
# 2021-04-06  118213.0  117176.0  117519.0  117499.0   6800800.0   117499.0
# 2021-04-07  118303.0  116748.0  117499.0  117624.0         0.0   117624.0
#
# [1233 rows x 6 columns]
